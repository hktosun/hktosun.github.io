# %% [raw]
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     } else {
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=true;
#     $('div.input').show()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Hide Code"></form>

# %% [markdown]
# <center> <h1> ECON 8602, Fall 2017, Final Exam </h1> </center>
# <center> <h2> Hasan K. Tosun</h2><center>

# %% [markdown]
# ## Q1
#
# #### a
# Each firm maximizes their profits by choosing the price. The equilibrium is where they best respond to each other.
#
# Firm 1's problem is:
#
# $$
# \begin{equation}
# \max_{p_1} s_1(p_1,p_2)(p_1-mc_1)
# \end{equation}
# $$
#
# Similarly, Firm 2's problem is
#
# $$
# \begin{equation}
# \max_{p_2} s_2(p_1,p_2)(p_2-mc_2)
# \end{equation}
# $$
#
# The FOC's are
#
# $$
# \begin{align}
# 0 & = \frac{\partial s_1(p_1^*(p_2),p_2)}{\partial p_1}(p_1^*(p_2)-mc_1) + s_1(p_1^*(p_2),p_2) \\
# 0 & = \frac{\partial s_2(p_1,p_2^*(p_1))}{\partial p_2}(p_2^*(p_1)-mc_2) + s_2(p_1,p_2^*(p_1)) \\
# \end{align}
# $$
#
# In equilibrium, they best respond to each other. Therefore, $(p_1^*,p_2^*)\equiv (p_1^*(p_2^*), p_2^*(p_1^*))$. Hence, $(p_1^*,p_2^*)$ is the equilibrium to the following system of equations:
#
#
# $$
# \begin{align}
# 0 & = \frac{\partial s_1(p_1^*,p_2^*)}{\partial p_1}(p_1^*-mc_1) + s_1(p_1^*,p_2^*) \\
# 0 & = \frac{\partial s_2(p_1^*,p_2^*)}{\partial p_2}(p_2^*-mc_2) + s_2(p_1^*,p_2^*) \\
# \end{align}
# $$
#
#
# #### b
# Now, assume that there is a fixed cost for each firm, $F_i$.
#
# Firm 1's problem is:
#
# $$
# \begin{equation}
# \max\{\max_{p_1} s_1(p_1,p_2)(p_1-mc_1) - F_1, 0\}
# \end{equation}
# $$
#
# Similarly, Firm 2's problem is
#
# $$
# \begin{equation}
# \max\{\max_{p_2} s_2(p_1,p_2)(p_2-mc_2) - F_2,0\}
# \end{equation}
# $$
#
# That is, in equilibrium, they may choose to not enter if the Bertrand-Nash equilibrium implies so. Therefore, let's first use the equilibrium where they both enter. Then, the profits would be:
#
# $$
# \begin{align}
# \pi_1 & = s_1(p_1^*,p_2^*)(p_1^*-mc_1) - F_1\\
# \pi_2 & = s_2(p_1^*,p_2^*)(p_2^*-mc_2) - F_2
# \end{align}
# $$
#
# But it might be that a firm would lose money if it enters, i.e. $\pi_j<0$. In this case, we assume that the other firm charges a price of $\infty$. So, we can write the equilibrium pricing functions as follows:
#
# $$
# p_1^{*F} = \left\{
# \begin{array}{cc}
# p_1^* & \text{ if } \pi_1\geq 0, \pi_2 \geq 0 \\
# argmax_{p_1} s_1(p_1,\infty)(p_1-mc_1) - F_1 & \text{ if } \pi_1\geq 0, \pi_2 < 0 \\
# \infty & \text{ if } \pi_1 < 0 \\
# \end{array}
# \right.
# $$
#
#
# $$
# p_2^{*F} = \left\{
# \begin{array}{cc}
# p_2^* & \text{ if } \pi_1\geq 0, \pi_2 \geq 0 \\
# argmax_{p_2} s_2(\infty,p_2)(p_2-mc_2) - F_2 & \text{ if } \pi_1< 0, \pi_2 \geq 0 \\
# \infty & \text{ if } \pi_2 < 0 \\
# \end{array}
# \right.
# $$
#
#
# #### c
#
# The price choice affect the profits in two ways:
# - Price is negatively correlated with the market share.
# - Price is positively correlated with the per-unit profit.
#
# The profit of Firm 1 with price $p_1$ is
#
# $$
# \begin{equation}
# \pi_1 = s_1(p_1,p_2)(p_1-mc_1)
# \end{equation}
# $$
#
# Suppose the firm decides to increase the price by $\Delta p_1$. Then, the new profits are
#
# $$
# \begin{equation}
# \pi'_1 = s_1(p_1+\Delta p_1,p_2)(p_1+\Delta p_1-mc_1)
# \end{equation}
# $$
#
# By increasing the price by $\Delta p_1$, the firm increases the profit-per-item by $\Delta p_1$. However, it loses some consumers, which results in the drop in the market share by $s_1(p_1,p_2)- s_1(p_1+\Delta p_1,p_2)$. So, if $\pi'_1>\pi_1$, then we say that there is still room for improvement in the profits for firm 1 by increasing the price, because the benefits from the inframarginal consumers exceeds the loss from the marginal consumers. And if $\pi'_1<\pi_1$, the firm shouldn't increase the price, since the benefits from the inframarginal consumers are less than the loss from the marginal consumers.
#
# Therefore, at the optimal prices, we can say that a price increase, $\Delta p_1>0$ will result in a decrease in profits since the profit loss from the marginal consumers is higher than the profit gains from the inframarginal consumers. And a price decrease, $\Delta p_1< 0 $ will result in a decrease in profits, since profit loss from the inframarginal consumers is higher than the profit gains from having new (marginal) consumers.

# %% [markdown]
# #### d
#
# Now, suppose the firms merge. Now, a single decision-maker chooses prices for both Firm 1 and Firm 2. Hence, the decision-maker's problem is
#
# $$
# \begin{equation}
# \max_{p_1,p_2} s_1(p_1,p_2)(p_1-mc_1) + s_2(p_1,p_2)(p_2-mc_2)
# \end{equation}
# $$
#
# Then, the FOCs are:
#
# $$
# \begin{align}
# [p_1]: 0 & = \frac{\partial s_1(p_1^*,p_2^*)}{\partial p_1}(p_1^*-mc_1) + s_1(p_1^*,p_2^*) + \frac{\partial s_2(p_1^*,p_2^*)}{\partial p_1}(p_2^*-c_2) \\
# [p_2]: 0 & = \frac{\partial s_1(p_1^*,p_2^*)}{\partial p_2}(p_1^*-mc_1) + s_2(p_1^*,p_2^*) + \frac{\partial s_2(p_1^*,p_2^*)}{\partial p_2}(p_2^*-c_2) \\
# \end{align}
# $$

# %% [markdown]
# #### e
#
# After the merger, Firm 1 doesn't have to compete with Firm 2. Because both prices are selected by the same decision-maker, and the decision-maker is concerned about the sum of the profits of two firms, prices are likely to be higher than the competition case.
#
# #### f
#
# If marginal costs decrease by 20%, then the new set of equations that characterizes the equilibrium are:
#
# $$
# \begin{align}
# [p_1]: 0 & = \frac{\partial s_1(p_1^*,p_2^*)}{\partial p_1}(p_1^*-0.8\cdot mc_1) + s_1(p_1^*,p_2^*) + \frac{\partial s_2(p_1^*,p_2^*)}{\partial p_1}(p_2^*-0.8\cdot c_2) \\
# [p_2]: 0 & = \frac{\partial s_1(p_1^*,p_2^*)}{\partial p_2}(p_1^*-0.8\cdot mc_1) + s_2(p_1^*,p_2^*) + \frac{\partial s_2(p_1^*,p_2^*)}{\partial p_2}(p_2^*-0.8\cdot c_2) \\
# \end{align}
# $$
#
#
# #### g
#
# There are two equations ($[p_1]$, $[p_2]$ above) and two unknowns ($p_1^*,p_2^*$). Hence, the solution is unique, i.e. there is a unique equilibrium.
#
# #### h
#
# Suppose (before the merger) Firm 1 develops a new good. Then, Firm 1's problem is
#
# Firm 1's problem is:
#
# $$
# \begin{equation}
# \max_{p_1,p_3} s_1(p_1,p_2,p_3)(p_1-mc_1) + s_3(p_1,p_2,p_3)(p_3-mc_3)
# \end{equation}
# $$
#
# Firm 2's problem is
#
# $$
# \begin{equation}
# \max_{p_2} s_2(p_1,p_2,p_3)(p_2-mc_2)
# \end{equation}
# $$
#
# So, the equations (FOCs) that characterizes the equilibrium are:
#
# $$
# \begin{align}
# [p_1]: & 0  = \frac{\partial s_1(p_1^*,p_2^*,p_3^*)}{\partial p_1}(p_1^*-mc_1) + s_1(p_1^*,p_2^*,p_3^*) + \frac{\partial s_3(p_1^*,p_2^*,p_3^*)}{\partial p_1}(p_3^*-mc_3) \\
# [p_2]: & 0  = \frac{\partial s_2(p_1^*,p_2^*,p_3^*)}{\partial p_2}(p_2^*-mc_2) + s_2(p_1^*,p_2^*,p_3^*) \\
# [p_3]: & 0  = \frac{\partial s_3(p_1^*,p_2^*,p_3^*)}{\partial p_3}(p_3^*-mc_3) + s_3(p_1^*,p_2^*,p_3^*) + \frac{\partial s_1(p_1^*,p_2^*,p_3^*)}{\partial p_3}(p_1^*-mc_1)\\
# \end{align}
# $$

# %% [markdown]
# ## Q2

# %% [markdown]
# An important note before we start: There are many errors in the data. So, our estimates doesn't reflect the truth, even if we use a "perfect" method. There are many movies that are actually exported to some countries, but in the data they are coded as they are not exported. I thank Minuk Kim for showing me those errors in the data.
#
# From now on, I assume that the data we use is correct.
#
# Suppose there is a fixed cost for "exporting" a movie. "Exporting" includes showing the movie in the country where the film is produced. Suppose also that the producers have rational expectations. Then, we can say that if a movie is actually exported, then the expected revenue is higher than the fixed cost, and if it is not exported, then the expected revenue is lower than the fixed cost.
#
# By following Pakes, Porter, Ho and Ishii (2015), let $J$ be the information set of the agents. Then,
#
# $$FC > E[revenue_j|J, export_j = 0] \;\;,\;\; E[revenue_j|J, export_j = 1]\geq FC .$$
#
# So, what we do in this exercise is that we sum the actual revenues when the movie is exported, and use it as the estimate for $E[revenue_j|J, export = 1]$ for all $j$; and sum the predicted revenues when the movie is not exporter, and use it as the estimate for $E[revenue_j|J, export = 0]$ for all $j$. With this method, we can construct a lowerbound an an upperbound for the fixed cost.
#
# The dataset contains all of the actual/predicted revenues for all movies originating from France (1), Germany (2), Spain (3), United Kingdom (4), and the United States (5) over the 2001-2009 period.
#
# This page will continue as follows. In the first part, I assume that the fixed cost is the same regardless of the origin, destination and the time period. In the second part, I make the fixed cost destination-country specific and estimate the bounds for each destination country. In the third part, I assume that the fixed cost is origin/destination pair specific and reestimate the bounds. Finally, in the fourth part, I divide the dataset into two by assuming that there is an earlier and a later period, and reestimate the bounds for the fixed cost. In all cases, I construct a 95% confidence interval by bootstrapping.

# %%
## Step zero: I'll transform the dataset so as to make it in the long format to make it easer to work with.)
library(tidyverse)
library(haven)
library(knitr)
library(kableExtra)
options(knitr.table.format = "html") 

data <- read_dta("predicted_revenue_for_exam.dta") 


data <-  data %>% select(-ls1, -ls2, -ls3, -ls4, -ls5) %>% 
  mutate_at(.vars=vars(starts_with("l")), .funs=funs(exp = exp(.))) %>%
  select(ono, year, s1, s2, s3, s4, s5, ends_with("exp"))


data1 <- data %>% filter(ono == 1) %>% select(year, s1, s2, s3, s4, s5, ends_with("1_exp")) # France  
data2 <- data %>% filter(ono == 2) %>% select(year, s1, s2, s3, s4, s5, ends_with("2_exp")) # Germany
data3 <- data %>% filter(ono == 3) %>% select(year, s1, s2, s3, s4, s5, ends_with("3_exp")) # Spain
data4 <- data %>% filter(ono == 4) %>% select(year, s1, s2, s3, s4, s5, ends_with("4_exp")) # UK
data5 <- data %>% filter(ono == 5) %>% select(year, s1, s2, s3, s4, s5, ends_with("5_exp")) # US

n1 <- nrow(data1)
n2 <- nrow(data2)
n3 <- nrow(data3)
n4 <- nrow(data4)
n5 <- nrow(data5)


nam <-c("s1", "s2", "s3", "s4", "s5")

enam1 <- c("ls1hat_1_exp", "ls2hat_1_exp", "ls3hat_1_exp", "ls4hat_1_exp", "ls5hat_1_exp")
enam2 <- c("ls1hat_2_exp", "ls2hat_2_exp", "ls3hat_2_exp", "ls4hat_2_exp", "ls5hat_2_exp")
enam3 <- c("ls1hat_3_exp", "ls2hat_3_exp", "ls3hat_3_exp", "ls4hat_3_exp", "ls5hat_3_exp")
enam4 <- c("ls1hat_4_exp", "ls2hat_4_exp", "ls3hat_4_exp", "ls4hat_4_exp", "ls5hat_4_exp")
enam5 <- c("ls1hat_5_exp", "ls2hat_5_exp", "ls3hat_5_exp", "ls4hat_5_exp", "ls5hat_5_exp")

datamat1 <- matrix(nrow = n1*5, ncol = 5)
datamat2 <- matrix(nrow = n2*5, ncol = 5)
datamat3 <- matrix(nrow = n3*5, ncol = 5)
datamat4 <- matrix(nrow = n4*5, ncol = 5)
datamat5 <- matrix(nrow = n5*5, ncol = 5)

datav <- list(data1,data2,data3,data4,data5)
datamatv <- list(datamat1,datamat2,datamat3,datamat4,datamat5)
enamv <- list(enam1,enam2,enam3,enam4,enam5)
n <- c(n1, n2, n3, n4, n5)


for (k in 1:5){
  for (j in 1:5){
    datamatv[[k]][,3]= k
    for (i in 1:n[[k]]){
      datamatv[[k]][i+(j-1)*n[[k]],4]= j
      datamatv[[k]][i+(j-1)*n[[k]],5]= as.numeric(datav[[k]][i,"year"])
      if(is.na(datav[[k]][i,nam[j]])==TRUE){
        datamatv[[k]][i+(j-1)*n[[k]],1] = 0
        datamatv[[k]][i+(j-1)*n[[k]],2] = as.numeric(datav[[k]][i,enamv[[k]][j]])
      }
      else{
        datamatv[[k]][i+(j-1)*n[[k]],1] = 1 
        datamatv[[k]][i+(j-1)*n[[k]],2] = as.numeric(datav[[k]][i,nam[j]])
      }
    }
  }
}

datamat <- rbind(datamatv[[1]],datamatv[[2]], datamatv[[3]],datamatv[[4]],datamatv[[5]])
dat <- datamat[!is.na(datamat[,2]),]
rm(n1,n2,n3,n4,n5, enam1,enam2,enam3,enam4,enam5,datamat1,datamat2,datamat3,datamat4,datamat5,data1,data2,data3,data4,data5,datamatv,datav,enamv,i,j,k,n,nam,datamat)

da <- as.tibble(dat)
names(da) <- c("export","revenue","origin","destination","year")

da <- da %>% mutate(y = 0*(year<2006) + 1*(year>=2006))
rm(dat,data)


N <- 1000

# %% [markdown]
# Suppose the fixed cost is the same regardless of the origin, destination and the time period. The interval estimates for the fixed cost parameter, and the confidence interval for it are as follows.
#
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:center;"> LB </th>
#    <th style="text-align:center;"> UB </th>
#    <th style="text-align:center;"> LB for 95% CI </th>
#    <th style="text-align:center;"> UB for 95% CI </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:center;"> 3102282 </td>
#    <td style="text-align:center;"> 9031771 </td>
#    <td style="text-align:center;"> 2969000 </td>
#    <td style="text-align:center;"> 9522865 </td>
#   </tr>
# </tbody>
# </table>

# %%
# PART A ------------------------------------------------------------------


bounds_all_o <- da %>% group_by(export) %>% summarize(me = sum(revenue)/n())

boot_all <- matrix(nrow = N, ncol = 3)

for(i in 1:N){
  bounds_all_b <- da %>% sample_frac(1,replace=TRUE) %>% group_by(export) %>% summarize(me = sum(revenue)/n())
  boot_all[i,1] <- as.numeric(bounds_all_b[1,2])
  boot_all[i,2] <- as.numeric(bounds_all_b[2,2])
}

ci <- 0 

kl_all <- 0
ku_all <- 0

while(ci < N*0.95){
  UB_all <- (bounds_all_o[2,2] + ku_all)
  LB_all <- (bounds_all_o[1,2] - kl_all)
  for (i in 1:N){
    boot_all[i,3] <- (boot_all[i,2]<UB_all)*(boot_all[i,1]>LB_all)
  }
  kl_all <- kl_all + sd(boot_all[,1])/20
  ku_all <- ku_all + sd(boot_all[,2])/20
  ci <- sum(boot_all[,3])
}


table_all <- matrix(nrow = 1, ncol = 4)
table_all[1,1] <- as.numeric(bounds_all_o[1,2])
table_all[1,2] <- as.numeric(bounds_all_o[2,2])
table_all[1,3] <- as.numeric(LB_all)
table_all[1,4] <- as.numeric(UB_all)
table_all <- as.data.frame(table_all)
names(table_all) <- c("LB", "UB", "LB for 95% CI", "UB for 95% CI")

rm(UB_all,LB_all,kl_all,ku_all,boot_all,bounds_all_b,bounds_all_o)

#kable(table_all, align="c")

# %% [markdown]
# Suppose the fixed cost is destination-country specific. The interval estimates for each fixed cost parameter, and the confidence interval for them are as follows.
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:center;"> Destination </th>
#    <th style="text-align:center;"> LB </th>
#    <th style="text-align:center;"> UB </th>
#    <th style="text-align:center;"> LB for 95% CI </th>
#    <th style="text-align:center;"> UB for 95% CI </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:center;"> France </td>
#    <td style="text-align:center;"> 361049.2 </td>
#    <td style="text-align:center;"> 2702563 </td>
#    <td style="text-align:center;"> 320839.5 </td>
#    <td style="text-align:center;"> 2959921 </td>
#   </tr>
#   <tr>
#    <td style="text-align:center;"> Germany </td>
#    <td style="text-align:center;"> 212900.4 </td>
#    <td style="text-align:center;"> 3446741 </td>
#    <td style="text-align:center;"> 190897.6 </td>
#    <td style="text-align:center;"> 3783024 </td>
#   </tr>
#   <tr>
#    <td style="text-align:center;"> Spain </td>
#    <td style="text-align:center;"> 272989.3 </td>
#    <td style="text-align:center;"> 2180745 </td>
#    <td style="text-align:center;"> 247867.9 </td>
#    <td style="text-align:center;"> 2343664 </td>
#   </tr>
#   <tr>
#    <td style="text-align:center;"> UK </td>
#    <td style="text-align:center;"> 432985.5 </td>
#    <td style="text-align:center;"> 4552534 </td>
#    <td style="text-align:center;"> 352501.2 </td>
#    <td style="text-align:center;"> 4984376 </td>
#   </tr>
#   <tr>
#    <td style="text-align:center;"> US </td>
#    <td style="text-align:center;"> 11708270.7 </td>
#    <td style="text-align:center;"> 52706275 </td>
#    <td style="text-align:center;"> 11271733.9 </td>
#    <td style="text-align:center;"> 55943480 </td>
#   </tr>
# </tbody>
# </table>

# %%
# PART B ------------------------------------------------------------------

bounds_dest_o <- da %>% group_by(destination, export) %>% summarize(me = sum(revenue)/n())

boot_dest <- matrix(nrow = N, ncol = 15)

for(i in 1:N){
  bounds_dest_b <- da %>% group_by(destination) %>% sample_frac(1,replace=TRUE) %>% group_by(destination, export) %>% summarize(me = sum(revenue)/n())
  for (j in 1:10){
    boot_dest[i,j] <- as.numeric(bounds_dest_b[j,3])
  }
}

LB_dest <- matrix(nrow = 5, ncol = 1)
UB_dest <- matrix(nrow = 5, ncol = 1)


for(j in 1:5){
  ci <- 0 
  ku_dest <- 0
  kl_dest <- 0
  while(ci < N*0.95){
    for (i in 1:N){
      UB_dest[j,1] <- as.numeric(bounds_dest_o[2*j,3]) + ku_dest
      LB_dest[j,1] <- as.numeric(bounds_dest_o[(2*j-1),3]) - kl_dest
      boot_dest[i,(10+j)] <- (boot_dest[i,2*j] < UB_dest[j,1])*(boot_dest[i,(2*j-1)] > LB_dest[j,1])
    }
    ku_dest <- ku_dest + sd(boot_dest[,2*j])/20
    kl_dest <- kl_dest + sd(boot_dest[,2*j-1])/20
    ci <- sum(boot_dest[,(10+j)])
  }
}
for(j in 1:5){
  LB_dest[j,1] <- as.numeric(LB_dest[j,1])
  UB_dest[j,1] <- as.numeric(UB_dest[j,1])
}

table_dest <- matrix(nrow = 5, ncol = 5)

for(j in 1:5){
  table_dest[j,1] <- j
  table_dest[j,2] <- as.numeric(bounds_dest_o[2*j-1,3])
  table_dest[j,3] <- as.numeric(bounds_dest_o[2*j,3])
  table_dest[j,4] <- LB_dest[j,1]
  table_dest[j,5] <- UB_dest[j,1]
}

table_dest <- as.data.frame(table_dest)
names(table_dest) <- c("destination", "LB", "UB", "LB for 95% CI", "UB for 95% CI")

rm(UB_dest,LB_dest,kl_dest,ku_dest,boot_dest,bounds_dest_b,bounds_dest_o)

#kable(table_dest, align="c")

# %% [markdown]
# Suppose the fixed cost is origin/destination-country pair specific. The interval estimates for each fixed cost parameter, and the confidence interval for them are as follows.
#
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:center;"> Origin </th>
#    <th style="text-align:center;"> Destination </th>
#    <th style="text-align:center;"> LB </th>
#    <th style="text-align:center;"> UB </th>
#    <th style="text-align:center;"> LB for 95% CI </th>
#    <th style="text-align:center;"> UB for 95% CI </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:center;"> France </td>
#    <td style="text-align:center;"> France </td>
#    <td style="text-align:center;"> 0.00 </td>
#    <td style="text-align:center;"> 1859457.5 </td>
#    <td style="text-align:center;"> 0.00 </td>
#    <td style="text-align:center;"> 2114288 </td>
#   </tr>
#   <tr>
#    <td style="text-align:center;"> France </td>
#    <td style="text-align:center;"> Germany </td>
#    <td style="text-align:center;"> 169060.93 </td>
#    <td style="text-align:center;"> 1538085.0 </td>
#    <td style="text-align:center;"> 154143.04 </td>
#    <td style="text-align:center;"> 1974766 </td>
#   </tr>
#   <tr>
#    <td style="text-align:center;"> France </td>
#    <td style="text-align:center;"> Spain </td>
#    <td style="text-align:center;"> 82759.60 </td>
#    <td style="text-align:center;"> 820780.2 </td>
#    <td style="text-align:center;"> 74955.14 </td>
#    <td style="text-align:center;"> 1043671 </td>
#   </tr>
#   <tr>
#    <td style="text-align:center;"> France </td>
#    <td style="text-align:center;"> UK </td>
#    <td style="text-align:center;"> 100257.57 </td>
#    <td style="text-align:center;"> 1171326.0 </td>
#    <td style="text-align:center;"> 93028.78 </td>
#    <td style="text-align:center;"> 1744379 </td>
#   </tr>
#   <tr>
#    <td style="text-align:center;"> France </td>
#    <td style="text-align:center;"> US </td>
#    <td style="text-align:center;"> 12103273.97 </td>
#    <td style="text-align:center;"> 26951366.6 </td>
#    <td style="text-align:center;"> 11552935.88 </td>
#    <td style="text-align:center;"> 36344883 </td>
#   </tr>
#   <tr>
#    <td style="text-align:center;"> Germany </td>
#    <td style="text-align:center;"> France </td>
#    <td style="text-align:center;"> 279879.80 </td>
#    <td style="text-align:center;"> 1634335.6 </td>
#    <td style="text-align:center;"> 254989.09 </td>
#    <td style="text-align:center;"> 2238301 </td>
#   </tr>
#   <tr>
#    <td style="text-align:center;"> Germany </td>
#    <td style="text-align:center;"> Germany </td>
#    <td style="text-align:center;"> 0.00 </td>
#    <td style="text-align:center;"> 2299025.4 </td>
#    <td style="text-align:center;"> 0.00 </td>
#    <td style="text-align:center;"> 2755001 </td>
#   </tr>
#   <tr>
#    <td style="text-align:center;"> Germany </td>
#    <td style="text-align:center;"> Spain </td>
#    <td style="text-align:center;"> 359208.23 </td>
#    <td style="text-align:center;"> 1282269.1 </td>
#    <td style="text-align:center;"> 341991.31 </td>
#    <td style="text-align:center;"> 1621647 </td>
#   </tr>
#   <tr>
#    <td style="text-align:center;"> Germany </td>
#    <td style="text-align:center;"> UK </td>
#    <td style="text-align:center;"> 238212.85 </td>
#    <td style="text-align:center;"> 2226601.1 </td>
#    <td style="text-align:center;"> 210852.85 </td>
#    <td style="text-align:center;"> 3184881 </td>
#   </tr>
#   <tr>
#    <td style="text-align:center;"> Germany </td>
#    <td style="text-align:center;"> US </td>
#    <td style="text-align:center;"> 26836328.52 </td>
#    <td style="text-align:center;"> 34809364.0 </td>
#    <td style="text-align:center;"> 25692071.63 </td>
#    <td style="text-align:center;"> 44832684 </td>
#   </tr>
#   <tr>
#    <td style="text-align:center;"> Spain </td>
#    <td style="text-align:center;"> France </td>
#    <td style="text-align:center;"> 123181.23 </td>
#    <td style="text-align:center;"> 1271165.1 </td>
#    <td style="text-align:center;"> 105220.43 </td>
#    <td style="text-align:center;"> 2084115 </td>
#   </tr>
#   <tr>
#    <td style="text-align:center;"> Spain </td>
#    <td style="text-align:center;"> Germany </td>
#    <td style="text-align:center;"> 99244.05 </td>
#    <td style="text-align:center;"> 892659.5 </td>
#    <td style="text-align:center;"> 80325.18 </td>
#    <td style="text-align:center;"> 1380623 </td>
#   </tr>
#   <tr>
#    <td style="text-align:center;"> Spain </td>
#    <td style="text-align:center;"> Spain </td>
#    <td style="text-align:center;"> 0.00 </td>
#    <td style="text-align:center;"> 938269.4 </td>
#    <td style="text-align:center;"> 0.00 </td>
#    <td style="text-align:center;"> 1104930 </td>
#   </tr>
#   <tr>
#    <td style="text-align:center;"> Spain </td>
#    <td style="text-align:center;"> UK </td>
#    <td style="text-align:center;"> 93760.17 </td>
#    <td style="text-align:center;"> 1177851.3 </td>
#    <td style="text-align:center;"> 83249.99 </td>
#    <td style="text-align:center;"> 1888515 </td>
#   </tr>
#   <tr>
#    <td style="text-align:center;"> Spain </td>
#    <td style="text-align:center;"> US </td>
#    <td style="text-align:center;"> 1588995.21 </td>
#    <td style="text-align:center;"> 23956977.7 </td>
#    <td style="text-align:center;"> 1221558.26 </td>
#    <td style="text-align:center;"> 33034956 </td>
#   </tr>
#   <tr>
#    <td style="text-align:center;"> UK </td>
#    <td style="text-align:center;"> France </td>
#    <td style="text-align:center;"> 211995.30 </td>
#    <td style="text-align:center;"> 3657762.4 </td>
#    <td style="text-align:center;"> 185994.69 </td>
#    <td style="text-align:center;"> 4886323 </td>
#   </tr>
#   <tr>
#    <td style="text-align:center;"> UK </td>
#    <td style="text-align:center;"> Germany </td>
#    <td style="text-align:center;"> 169155.95 </td>
#    <td style="text-align:center;"> 4940776.7 </td>
#    <td style="text-align:center;"> 148100.17 </td>
#    <td style="text-align:center;"> 6772770 </td>
#   </tr>
#   <tr>
#    <td style="text-align:center;"> UK </td>
#    <td style="text-align:center;"> Spain </td>
#    <td style="text-align:center;"> 157517.30 </td>
#    <td style="text-align:center;"> 2229607.5 </td>
#    <td style="text-align:center;"> 143722.16 </td>
#    <td style="text-align:center;"> 2775829 </td>
#   </tr>
#   <tr>
#    <td style="text-align:center;"> UK </td>
#    <td style="text-align:center;"> UK </td>
#    <td style="text-align:center;"> 0.00 </td>
#    <td style="text-align:center;"> 2415361.9 </td>
#    <td style="text-align:center;"> 0.00 </td>
#    <td style="text-align:center;"> 3039797 </td>
#   </tr>
#   <tr>
#    <td style="text-align:center;"> UK </td>
#    <td style="text-align:center;"> US </td>
#    <td style="text-align:center;"> 6678157.37 </td>
#    <td style="text-align:center;"> 52944036.5 </td>
#    <td style="text-align:center;"> 6149831.38 </td>
#    <td style="text-align:center;"> 68058221 </td>
#   </tr>
#   <tr>
#    <td style="text-align:center;"> US </td>
#    <td style="text-align:center;"> France </td>
#    <td style="text-align:center;"> 1191521.14 </td>
#    <td style="text-align:center;"> 4052857.6 </td>
#    <td style="text-align:center;"> 970332.70 </td>
#    <td style="text-align:center;"> 4522676 </td>
#   </tr>
#   <tr>
#    <td style="text-align:center;"> US </td>
#    <td style="text-align:center;"> Germany </td>
#    <td style="text-align:center;"> 863571.71 </td>
#    <td style="text-align:center;"> 4258577.1 </td>
#    <td style="text-align:center;"> 642684.54 </td>
#    <td style="text-align:center;"> 4734641 </td>
#   </tr>
#   <tr>
#    <td style="text-align:center;"> US </td>
#    <td style="text-align:center;"> Spain </td>
#    <td style="text-align:center;"> 1340623.85 </td>
#    <td style="text-align:center;"> 3202683.8 </td>
#    <td style="text-align:center;"> 1115340.02 </td>
#    <td style="text-align:center;"> 3489374 </td>
#   </tr>
#   <tr>
#    <td style="text-align:center;"> US </td>
#    <td style="text-align:center;"> UK </td>
#    <td style="text-align:center;"> 3642880.68 </td>
#    <td style="text-align:center;"> 6463238.6 </td>
#    <td style="text-align:center;"> 2753901.53 </td>
#    <td style="text-align:center;"> 7118926 </td>
#   </tr>
#   <tr>
#    <td style="text-align:center;"> US </td>
#    <td style="text-align:center;"> US </td>
#    <td style="text-align:center;"> 0.00 </td>
#    <td style="text-align:center;"> 53788854.3 </td>
#    <td style="text-align:center;"> 0.00 </td>
#    <td style="text-align:center;"> 56869135 </td>
#   </tr>
# </tbody>
# </table>

# %%
# PART C ------------------------------------------------------------------

bounds_origin_dest_o <- da %>% group_by(origin, destination, export) %>% summarize(me = sum(revenue)/n())

bounds_origin_dest_o_own <- bounds_origin_dest_o %>% filter((origin == destination))
bounds_origin_dest_o_cross <- bounds_origin_dest_o %>% filter((origin != destination))


boot_origin_dest <- matrix(nrow = N, ncol = 75)

for(i in 1:N){
  bounds_origin_dest_b <- da %>% group_by(origin, destination, export) %>% sample_frac(1,replace=TRUE) %>% group_by(origin, destination, export) %>% summarize(me = sum(revenue)/n())
  bounds_origin_dest_b_own <- bounds_origin_dest_b %>% filter((origin == destination))
  bounds_origin_dest_b_cross <- bounds_origin_dest_b %>% filter((origin != destination))
  
  for (j in 1:40){
    boot_origin_dest[i,j] <- as.numeric(bounds_origin_dest_b_cross[j,4])
  }

  for(j in 41:45){
    boot_origin_dest[i,j] <- 0
  }
  for(j in 46:50){
    boot_origin_dest[i,j] <- as.numeric(bounds_origin_dest_b_own[j-45,4])
  }
  
}

LB_origin_dest <- matrix(nrow = 25, ncol = 1)
UB_origin_dest <- matrix(nrow = 25, ncol = 1)


for(j in 1:20){
  ci <- 0 
  ku_origin_dest <- 0
  kl_origin_dest <- 0
  while(ci < N*0.95){
    for (i in 1:N){
      UB_origin_dest[j,1] <- as.numeric(bounds_origin_dest_o_cross[2*j,4]) + ku_origin_dest
      LB_origin_dest[j,1] <- as.numeric(bounds_origin_dest_o_cross[(2*j-1),4]) - kl_origin_dest
      boot_origin_dest[i,(50+j)] <- (boot_origin_dest[i,2*j] < UB_origin_dest[j])*(boot_origin_dest[i,(2*j-1)] > LB_origin_dest[j])
    }
    ku_origin_dest <- ku_origin_dest + sd(boot_origin_dest[,2*j])/20
    kl_origin_dest <- kl_origin_dest + sd(boot_origin_dest[,2*j-1])/20
    ci <- sum(boot_origin_dest[,(50+j)])
  }
}

for(j in 1:5){
  ci <- 0 
  ku_origin_dest <- 0
  while(ci < N*0.95){
    for (i in 1:N){
      UB_origin_dest[20+j,1] <- as.numeric(bounds_origin_dest_o_own[j,4]) + ku_origin_dest
      LB_origin_dest[20+j,1] <- 0
      boot_origin_dest[i,(70+j)] <- (boot_origin_dest[i,45+j] < UB_origin_dest[20+j])
    }
    ku_origin_dest <- ku_origin_dest + sd(boot_origin_dest[,45+j])/20
    ci <- sum(boot_origin_dest[,(70+j)])
  }
}



for(j in 1:25){
  LB_origin_dest[j,1] <- as.numeric(LB_origin_dest[j,1])
  UB_origin_dest[j,1] <- as.numeric(UB_origin_dest[j,1])
}

table_origin_dest <- matrix(nrow = 25, ncol = 6)

for(j in 1:25){
  if(j<=20)
  {
    table_origin_dest[j,1] <- as.numeric(bounds_origin_dest_o_cross[2*j-1,1])
    table_origin_dest[j,2] <- as.numeric(bounds_origin_dest_o_cross[2*j-1,2])
    table_origin_dest[j,3] <- as.numeric(bounds_origin_dest_o_cross[2*j-1,4])
    table_origin_dest[j,4] <- as.numeric(bounds_origin_dest_o_cross[2*j,4])
    table_origin_dest[j,5] <- LB_origin_dest[j,1]
    table_origin_dest[j,6] <- UB_origin_dest[j,1]
  }
  else{
    table_origin_dest[j,1] <- as.numeric(bounds_origin_dest_o_own[j-20,1])
    table_origin_dest[j,2] <- as.numeric(bounds_origin_dest_o_own[j-20,2])
    table_origin_dest[j,3] <- 0
    table_origin_dest[j,4] <- as.numeric(bounds_origin_dest_o_own[j-20,4])
    table_origin_dest[j,5] <- 0
    table_origin_dest[j,6] <- UB_origin_dest[j,1]
    
  }
}

table_origin_dest <- as.tibble(table_origin_dest)
names(table_origin_dest) <- c("origin","destination", "LB", "UB", "LB for 95% CI", "UB for 95% CI")
table_origin_dest <- arrange(table_origin_dest, origin, destination)

rm(UB_origin_dest,LB_origin_dest,kl_origin_dest,ku_origin_dest,boot_origin_dest,bounds_origin_dest_b,bounds_origin_dest_b_own,bounds_origin_dest_b_cross,bounds_origin_dest_o, bounds_origin_dest_o_own,bounds_origin_dest_o_cross)
#kable(table_origin_dest, align="c")

# %% [markdown]
# Finally, I break up the sample into an early period (2001-2005) and a later period (2006-2009) and redo Part B above. Therefore, we assume that the fixed cost is different for each destination and the time period. The interval estimates for each fixed cost parameter, and the confidence interval for them are as follows.
#
# <table>
#  <thead>
#   <tr>
#    <th style="text-align:center;"> Destination </th>
#    <th style="text-align:center;"> Period </th>
#    <th style="text-align:center;"> LB </th>
#    <th style="text-align:center;"> UB </th>
#    <th style="text-align:center;"> LB for 95% CI </th>
#    <th style="text-align:center;"> UB for 95% CI </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:center;"> France </td>
#    <td style="text-align:center;"> 2001-2005 </td>
#    <td style="text-align:center;"> 477082.7 </td>
#    <td style="text-align:center;"> 2415459 </td>
#    <td style="text-align:center;"> 403793.1 </td>
#    <td style="text-align:center;"> 2691227 </td>
#   </tr>
#   <tr>
#    <td style="text-align:center;"> France </td>
#    <td style="text-align:center;"> 2006-2009 </td>
#    <td style="text-align:center;"> 277002.4 </td>
#    <td style="text-align:center;"> 2991785 </td>
#    <td style="text-align:center;"> 238927.2 </td>
#    <td style="text-align:center;"> 3372621 </td>
#   </tr>
#   <tr>
#    <td style="text-align:center;"> Germany </td>
#    <td style="text-align:center;"> 2001-2005 </td>
#    <td style="text-align:center;"> 195066.8 </td>
#    <td style="text-align:center;"> 3675918 </td>
#    <td style="text-align:center;"> 169927.0 </td>
#    <td style="text-align:center;"> 4094222 </td>
#   </tr>
#   <tr>
#    <td style="text-align:center;"> Germany </td>
#    <td style="text-align:center;"> 2006-2009 </td>
#    <td style="text-align:center;"> 228379.6 </td>
#    <td style="text-align:center;"> 3234836 </td>
#    <td style="text-align:center;"> 193522.8 </td>
#    <td style="text-align:center;"> 3694059 </td>
#   </tr>
#   <tr>
#    <td style="text-align:center;"> Spain </td>
#    <td style="text-align:center;"> 2001-2005 </td>
#    <td style="text-align:center;"> 325264.2 </td>
#    <td style="text-align:center;"> 2084023 </td>
#    <td style="text-align:center;"> 275604.1 </td>
#    <td style="text-align:center;"> 2290245 </td>
#   </tr>
#   <tr>
#    <td style="text-align:center;"> Spain </td>
#    <td style="text-align:center;"> 2006-2009 </td>
#    <td style="text-align:center;"> 232038.0 </td>
#    <td style="text-align:center;"> 2279907 </td>
#    <td style="text-align:center;"> 206285.8 </td>
#    <td style="text-align:center;"> 2541582 </td>
#   </tr>
#   <tr>
#    <td style="text-align:center;"> UK </td>
#    <td style="text-align:center;"> 2001-2005 </td>
#    <td style="text-align:center;"> 588149.1 </td>
#    <td style="text-align:center;"> 5444857 </td>
#    <td style="text-align:center;"> 453161.7 </td>
#    <td style="text-align:center;"> 6143122 </td>
#   </tr>
#   <tr>
#    <td style="text-align:center;"> UK </td>
#    <td style="text-align:center;"> 2006-2009 </td>
#    <td style="text-align:center;"> 272739.5 </td>
#    <td style="text-align:center;"> 3977301 </td>
#    <td style="text-align:center;"> 202501.4 </td>
#    <td style="text-align:center;"> 4538428 </td>
#   </tr>
#   <tr>
#    <td style="text-align:center;"> US </td>
#    <td style="text-align:center;"> 2001-2005 </td>
#    <td style="text-align:center;"> 11783720.6 </td>
#    <td style="text-align:center;"> 52755229 </td>
#    <td style="text-align:center;"> 11175625.0 </td>
#    <td style="text-align:center;"> 56942171 </td>
#   </tr>
#   <tr>
#    <td style="text-align:center;"> US </td>
#    <td style="text-align:center;"> 2006-2009 </td>
#    <td style="text-align:center;"> 11647600.1 </td>
#    <td style="text-align:center;"> 52645105 </td>
#    <td style="text-align:center;"> 11058476.5 </td>
#    <td style="text-align:center;"> 57589142 </td>
#   </tr>
# </tbody>
# </table>

# %%
# PART D ------------------------------------------------------------------

bounds_dest_year_o <- da %>% group_by(destination, y, export) %>% summarize(me = sum(revenue)/n())


boot_dest_year <- matrix(nrow = N, ncol = 30)

for(i in 1:N){
  bounds_dest_year_b <- da %>% group_by(destination, y) %>% sample_frac(1,replace=TRUE) %>% group_by(destination, y, export) %>% summarize(me = sum(revenue)/n())
  for (j in 1:20){
    boot_dest_year[i,j] <- as.numeric(bounds_dest_year_b[j,4])
  }
}

LB_dest_year <- matrix(nrow = 10, ncol = 1)
UB_dest_year <- matrix(nrow = 10, ncol = 1)


for(j in 1:10){
  ci <- 0 
  ku_dest_year <- 0
  kl_dest_year <- 0
  while(ci < N*0.95){
    for (i in 1:N){
      UB_dest_year[j,1] <- as.numeric(bounds_dest_year_o[2*j,4]) + ku_dest_year
      LB_dest_year[j,1] <- as.numeric(bounds_dest_year_o[(2*j-1),4]) - kl_dest_year
      boot_dest_year[i,(20+j)] <- (boot_dest_year[i,2*j] < UB_dest_year[j,1])*(boot_dest_year[i,(2*j-1)] > LB_dest_year[j,1])
    }
    ku_dest_year <- ku_dest_year + sd(boot_dest_year[,2*j])/20
    kl_dest_year <- kl_dest_year + sd(boot_dest_year[,2*j-1])/20
    ci <- sum(boot_dest_year[,(20+j)])
  }
}
for(j in 1:10){
  LB_dest_year[j,1] <- as.numeric(LB_dest_year[j,1])
  UB_dest_year[j,1] <- as.numeric(UB_dest_year[j,1])
}

table_dest_year <- matrix(nrow = 10, ncol = 6)

for(j in 1:10){
  table_dest_year[j,1] <- ceiling(j/2)
  table_dest_year[j,2] <- (j%%2 == 0)*1
  table_dest_year[j,3] <- as.numeric(bounds_dest_year_o[2*j-1,4])
  table_dest_year[j,4] <- as.numeric(bounds_dest_year_o[2*j,4])
  table_dest_year[j,5] <- LB_dest_year[j,1]
  table_dest_year[j,6] <- UB_dest_year[j,1]
}

table_dest_year <- as.data.frame(table_dest_year)
names(table_dest_year) <- c("destination", "period", "LB", "UB", "LB for 95% CI", "UB for 95% CI")
rm(UB_dest_year,LB_dest_year,kl_dest_year,ku_dest_year,ci,boot_dest_year,bounds_dest_year_b,bounds_dest_year_o)

#kable(table_dest_year, align="c")

# %% [markdown]
# Because there is not a language barrier, I expected the fixed cost for US-UK pair to be smaller than US-Spain, or US-France. Our estimates doesn't support that. I didn't find a clear movement of the fixed cost over time. However, Minuk and I detected too many cases where the US movies that are actually exported to UK are coded as not exported, and the predicted revenue is given instead of the actual revenue. We believe that it is those observations that makes our estimates inconsistent with our intuition.
